# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util
import pandas as pd

# %%
#Function for getting all the user's saved (favorited) tracks
def get_all_saved_tracks(fav_df, user, limit_step=50):
    for offset in range(0, 10000000000000000000000, limit_step):
        r = user.current_user_saved_tracks(
            limit=limit_step,
            offset=offset,
        )
        #print(r)               
        for idx, item in enumerate(r['items']):
            d = item['track']
            band_id = d['artists'][0]['id']
            band_name = d['artists'][0]['name']
            album_name = d['album']['name']
            release_date = d['album']['release_date']
            total_tracks = d['album']['total_tracks']
            album_id = d['album']['id']
            track_id = d['id']
            track_name = d['name']
            duration_ms = d['duration_ms']
            explicit = d['explicit']
            added_at = item['added_at']

            temp_df = pd.DataFrame({'artist_id':band_id,'artist_name':band_name,'album_name':album_name,'album_release_date':release_date,
                                'album_total_tracks':total_tracks,'album_id':album_id, 'track_id':track_id, 'track_name':track_name, 'duration_ms':duration_ms,
                                'explicit':explicit, 'added_at':added_at}, index = ['band_id'])

            #For concat(), need to explicitly caste boolean/datetime values as boolean and datetime
            temp_df['explicit'] = temp_df['explicit'].astype('boolean')
            #temp_df['added_at'] = temp_df['added_at'].astype('datetime64')

            fav_df = pd.concat([fav_df, temp_df], ignore_index=True)

        if offset > int(r['total']):
            break
        
    return fav_df

# %%
#Main
fav_df = pd.DataFrame(columns=["artist_id","artist_name","album_id","album_name","album_release_date",
                  "album_total_tracks", "track_id", "track_name","duration_ms","explicit","added_at"])

#Set environment API variables
# %set_env SPOTIPY_CLIENT_ID = 9cdef0bc741e471385b100af843c28c5
# %set_env SPOTIPY_CLIENT_SECRET = a0820dd07a3e4d8facb51bb5ed5130a2
# %set_env SPOTIPY_REDIRECT_URI= http://localhost:8888/callback

#Set token and login credentials
token = util.prompt_for_user_token(scope="user-library-read")
sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())
user = sp

#Get all user saved (favorited) tracks
fav_df = get_all_saved_tracks(fav_df, user)

fav_df.to_csv(r'~/Documents/spotify_analysis/fav_list.csv',encoding='utf-8-sig')
print('-----------------------------------')
print('Saved to .csv in project directory.')
print('-----------------------------------')
# Out:
# env: SPOTIPY_CLIENT_ID=9cdef0bc741e471385b100af843c28c5
# env: SPOTIPY_CLIENT_SECRET=a0820dd07a3e4d8facb51bb5ed5130a2
# env: SPOTIPY_REDIRECT_URI=http://localhost:8888/callback
# /tmp/ipykernel_5900/1230709292.py:31: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   fav_df = pd.concat([fav_df, temp_df], ignore_index=True)
# -----------------------------------
# Saved to .csv in project directory.
# -----------------------------------

# %%
fav_df
# Out:
#                    artist_id        artist_name                album_id  \
# 0     3pulcT2wt7FEG10lQlqDJL        Amon Amarth  3cQfALGRSzDeohPsXkF6X3
# 1     3pulcT2wt7FEG10lQlqDJL        Amon Amarth  79GLbXCHnsOG9TBzvtS3sy
# 2     4FmJD0mpgQ70SNt2EKK8tq   Miracle Of Sound  5HF0MS5bnKVPe33rSEuYdZ
# 3     4FmJD0mpgQ70SNt2EKK8tq   Miracle Of Sound  1QhzS64CeOjPBFLKuxnS6k
# 4     0WPCPYm5IDNtQjuJOGNPcy  Brothers of Metal  2tWp1AYC1fW4I1gElf1s3V
# ...                      ...                ...                     ...
# 1366  2ye2Wgw4gimLv2eAKyk1NB          Metallica  28EHPejVjC5XdLrR0I9baK
# 1367  2ye2Wgw4gimLv2eAKyk1NB          Metallica  28EHPejVjC5XdLrR0I9baK
# 1368  2ye2Wgw4gimLv2eAKyk1NB          Metallica  51j7xzjeJvnOGYJ9yAk4OC
# 1369  2ye2Wgw4gimLv2eAKyk1NB          Metallica  3MTvwb2Yk4kSqVOi4VUlj8
# 1370  2ye2Wgw4gimLv2eAKyk1NB          Metallica  3MTvwb2Yk4kSqVOi4VUlj8
#
#                 album_name album_release_date album_total_tracks  \
# 0     Deceiver of the Gods         2013-06-25                 10
# 1               Jomsviking         2016-03-25                 11
# 2     Skal (Metal Version)         2023-03-24                  1
# 3                     Skal         2023-03-10                  1
# 4                Berserkir         2022-12-02                  2
# ...                    ...                ...                ...
# 1366    Ride The Lightning               1984                  8
# 1367    Ride The Lightning               1984                  8
# 1368          Kill 'Em All               1983                 10
# 1369   And Justice For All         1988-09-05                  9
# 1370   And Justice For All         1988-09-05                  9
#
#                     track_id              track_name duration_ms  explicit  \
# 0     7jcCt0VtoIsQ1rIcITvplO           Shape Shifter      242506     False
# 1     5gNyrx8elXaXXs3vFC1ufZ        Raise Your Horns      263786     False
# 2     1Qt5SbPsqxba4mhtF76o0I    Skal - Metal Version      179643     False
# 3     4SO5r9cjaokv3HXuP1IXV5                    Skal      170312     False
# 4     314iEiVWW8TGvV90ID3PIr   The Other Son of Odin      205626     False
# ...                      ...                     ...         ...       ...
# 1366  4c1LxlkHYWuBlBawzLTZ4r      Ride The Lightning      396360     False
# 1367  498g11Ee3Ht9YwS2q0kfMl    Fight Fire With Fire      284853     False
# 1368  6Pm3JzPfodgQ1tD5AWjGwk          Seek & Destroy      412000     False
# 1369  3Y3PSLydY5gz9GPy2O62yo  ...And Justice For All      585400     False
# 1370  1txnuzQBhiIkR69tszEvM7               Blackened      400866     False
#
#                 added_at
# 0    2023-04-06 12:46:45
# 1    2023-04-06 12:41:25
# 2    2023-04-06 12:32:03
# 3    2023-03-30 06:05:38
# 4    2023-03-30 06:05:33
# ...                  ...
# 1366 2014-12-17 08:35:00
# 1367 2014-12-17 08:34:59
# 1368 2014-12-17 08:34:53
# 1369 2014-12-17 08:34:49
# 1370 2014-12-17 08:34:48
#
# [1371 rows x 11 columns]

# %%
fav_df.dtypes
# Out:
# artist_id                     object
# artist_name                   object
# album_id                      object
# album_name                    object
# album_release_date            object
# album_total_tracks            object
# track_id                      object
# track_name                    object
# duration_ms                   object
# explicit                     boolean
# added_at              datetime64[ns]
# dtype: object

# %%
test_df = fav_df[['artist_id','artist_name','album_id','album_name','album_release_date','album_total_tracks']]

# %%
test_df = test_df.drop_duplicates()
fav_df = fav_df.drop_duplicates()

# %%
import psycopg2
import numpy as np
import psycopg2.extras as extras
import pandas as pd

# bulk insert to postgreSQL db 
def execute_values(conn, fav_df, table):
  
    tuples = [tuple(x) for x in fav_df.to_numpy()]
  
    cols = ','.join(list(fav_df.columns))
    # SQL query to execute
    query = """
            INSERT INTO %s(%s)
            VALUES %%s
            ON CONFLICT DO NOTHING
            """ % (table, cols)
     
    cursor = conn.cursor()
    try:
        extras.execute_values(cursor, query, tuples)
        conn.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        conn.rollback()
        cursor.close()
        return 1
    print("the dataframe is inserted")
    cursor.close()

conn = psycopg2.connect(database="dspjmain",
                        host="localhost",
                        user="postgres",
                        password="derekgrammer",
                        port="5432")
  
execute_values(conn, fav_df, 'dspjschema.track_master')
# Out:
# the dataframe is inserted
