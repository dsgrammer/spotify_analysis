# %%
import requests
import pandas as pd
import time

# %%
AUTH_URL = 'https://accounts.spotify.com/api/token'
# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': '9cdef0bc741e471385b100af843c28c5',
    'client_secret': 'a0820dd07a3e4d8facb51bb5ed5130a2',
})
# convert the response to JSON
auth_response_data = auth_response.json()
# save the access token
access_token = auth_response_data['access_token']
# used for authenticating all API calls
headers = {'Authorization': 'Bearer {token}'.format(token=access_token)}

# %%
#get track audio features
def get_audio_features(feature_df,track_id):
    # pull all tracks from this album
    for track in track_id:
        track_id = track
        r = requests.get(BASE_URL + 'audio-features/' + track_id, 
                         headers=headers)
        d = r.json()
        time.sleep(1)
        
        track_id = d['id']
        danceability = d['danceability']
        energy = d['energy']
        key = d['key']
        loudness = d['loudness']
        mode = d['mode']
        speechiness = d['speechiness']
        acousticness = d['acousticness']
        instrumentalness = d['instrumentalness']
        liveness = d['liveness']
        valence = d['valence']
        tempo = d['tempo']
        time_signature = d['time_signature']
        
        #save data in pd dataframe
        ##feature_df = feature_df.append({'track_id':track_id,'danceability': danceability,'energy': energy,
        ##                            'key': key,'loudness': loudness,'mode': mode,'speechiness': speechiness,'acousticness': acousticness,
        ##                            'instrumentalness': instrumentalness,'liveness': liveness,'valence': valence,'tempo': tempo,
        ##                            'time_signature': time_signature},ignore_index=True)
        temp_df = pd.DataFrame({'track_id':track_id,'danceability': danceability,'energy': energy,
                                    'key': key,'loudness': loudness,'mode': mode,'speechiness': speechiness,'acousticness': acousticness,
                                    'instrumentalness': instrumentalness,'liveness': liveness,'valence': valence,'tempo': tempo,
                                    'time_signature': time_signature},index=[1])
        feature_df = pd.concat([feature_df, temp_df], ignore_index=True)
    return feature_df

# %%
#Main
BASE_URL = 'https://api.spotify.com/v1/'
track_df = pd.read_csv(r'~/Documents/spotify_analysis/test-csvs/track_list.csv')
track_id = track_df.loc[:,'track_id']
feature_df = pd.DataFrame(columns=["track_id","danceability","energy","key","loudness","mode","speechiness","acousticness","instrumentalness",
                            "liveness","valence","tempo","time_signature"])
feature_df = get_audio_features(feature_df, track_id)

feature_df.to_csv(r'~/Documents/spotify_analysis/test-csvs/audio-features.csv',encoding='utf-8-sig')
print('-----------------------------------')
print('Saved to .csv in project directory.')
print('-----------------------------------')
# Out:
# /tmp/ipykernel_4790/1874076806.py:34: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feature_df = pd.concat([feature_df, temp_df], ignore_index=True)
# -----------------------------------
# Saved to .csv in project directory.
# -----------------------------------

# %%
"""
BASE_URL = 'https://api.spotify.com/v1/'
track_id = '0HRrX9EWtLIy6UC2nS7p85'
r = requests.get(BASE_URL + 'audio-features/' + track_id, 
                    headers=headers)
d = r.json()
time.sleep(1)

import json
with open('api_request_result.json', 'w', encoding='utf-8') as f:
    json.dump(d, f, ensure_ascii=False, indent=4)
"""
# Out:
# "\nBASE_URL = 'https://api.spotify.com/v1/'\ntrack_id = '0HRrX9EWtLIy6UC2nS7p85'\nr = requests.get(BASE_URL + 'audio-features/' + track_id, \n                    headers=headers)\nd = r.json()\ntime.sleep(1)\n\nimport json\nwith open('api_request_result.json', 'w', encoding='utf-8') as f:\n    json.dump(d, f, ensure_ascii=False, indent=4)\n"

# %%
feature_df
# Out:
#                   track_id  danceability  energy key  loudness mode  \
# 0   6Yds8wmt3JH2P5MYTVwl0g         0.431   0.299   4   -13.364    0
# 1   6FUXgvzbMrMCzAuYGIiGIl         0.468   0.803   4    -6.653    0
# 2   3Pb4dfKyGnpouV7hAZyo3H         0.497   0.899  11    -7.590    1
# 3   3OcgNPvAcDmNB9Idcdh4sA         0.513   0.881   9    -6.720    0
# 4   313f3J4lGMA0irUrWaUXUh         0.483   0.904   7    -6.054    1
# 5   6tFw53jGBwl3lqrqA9OQY8         0.351   0.932   6    -6.419    1
# 6   44zTeHWsNcuJZ3ZawZgWhI         0.454   0.495   0    -8.354    1
# 7   3z3NxilFXnpdwl2zBhENmB         0.505   0.855   0    -7.386    1
# 8   3AO5tBMSL9MMTdwDzqgUGR         0.272   0.801  10    -7.949    0
# 9   0Hg6cD0VepM1bnjl0lObQ3         0.476   0.713   7    -7.024    1
# 10  1V8Kp81sYUxX2xfFhp2gck         0.453   0.688   8    -7.818    1
# 11  1npDycvcBm6bTnaajiTv3X         0.492   0.955  11    -6.289    1
# 12  5G3fOooycAOronSubOZnIS         0.482   0.775   6    -6.644    1
# 13  1OnHeldjfrF6Zx3FnS1zQ5         0.506   0.911   1    -5.341    1
# 14  1d17u8gNyjAwhp9N9C7Io5         0.462   0.805  10    -5.759    0
# 15  4kpWVGdFjBSoCkIcHVlTqn         0.548   0.878  11    -5.758    0
# 16  37oLbcJ5oouA1PJJsKOjub         0.267   0.880  10    -5.730    0
# 17  5WhNrwy16pS3xYKDxVpTGc         0.347   0.432  11    -9.331    0
# 18  3V417nSM4Ilh0Tt5CqustV         0.469   0.743   1    -5.570    0
# 19  6Dh4wplHHsBbxm5R8QADMS         0.272   0.825  11    -5.655    1
# 20  4jYb6f8EFtqO1PiV7dVkL5         0.429   0.884  11    -5.125    0
# 21  4JKo9tyUlKXOH90xta27gg         0.376   0.852   9    -4.920    1
# 22  0mQlLUtW0JNrYm2amqv7C4         0.403   0.723   4    -5.655    0
# 23  2mKwZxYMyEm3hg9tIyn8oL         0.270   0.893  10    -5.746    0
# 24  3gwzxF38VZka9epVs9KXkw         0.439   0.917   9    -5.183    1
# 25  1KuNk1ZZPTZKwjjo1Vdw9G         0.541   0.912   0    -5.491    1
# 26  0JV2FO1WcnNA5g1HcO0Oky         0.459   0.805   1    -6.424    1
#
#     speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0        0.0824      0.024600          0.000005    0.3020   0.1360   97.220
# 1        0.0894      0.002410          0.000000    0.4530   0.4090   87.380
# 2        0.0744      0.000267          0.000000    0.1070   0.3910  145.049
# 3        0.0521      0.000083          0.001230    0.0545   0.1580   95.023
# 4        0.0574      0.000434          0.000000    0.2490   0.3930  146.006
# 5        0.1270      0.001020          0.000012    0.7500   0.2470  169.905
# 6        0.0296      0.070500          0.000015    0.1000   0.2900  149.562
# 7        0.0532      0.000713          0.000087    0.0881   0.4350  100.039
# 8        0.0836      0.005480          0.001120    0.0961   0.0893  107.292
# 9        0.0667      0.000838          0.000206    0.0802   0.5640  183.032
# 10       0.0321      0.003850          0.000157    0.0805   0.3450   87.540
# 11       0.0775      0.000043          0.000087    0.3950   0.3860  144.974
# 12       0.0490      0.002090          0.000000    0.1190   0.3100  136.056
# 13       0.0397      0.000019          0.028800    0.3350   0.2760  112.489
# 14       0.0337      0.007230          0.000053    0.3080   0.4870   84.994
# 15       0.0449      0.000073          0.039500    0.4240   0.1370  135.052
# 16       0.0609      0.000112          0.543000    0.3400   0.1410  139.995
# 17       0.0332      0.710000          0.000018    0.3580   0.3050   80.673
# 18       0.0272      0.002220          0.000111    0.2760   0.4810   86.953
# 19       0.0398      0.000014          0.719000    0.3930   0.0783  104.953
# 20       0.0430      0.000012          0.046100    0.4760   0.6290   92.965
# 21       0.0453      0.000073          0.005670    0.1150   0.4160  157.934
# 22       0.0325      0.000083          0.000022    0.3290   0.4610  155.040
# 23       0.0705      0.000123          0.130000    0.4090   0.3730  150.071
# 24       0.0434      0.000061          0.037700    0.1170   0.3880  158.019
# 25       0.0455      0.000093          0.005180    0.1680   0.1390  120.050
# 26       0.0370      0.000033          0.019700    0.6680   0.1440  114.976
#
#    time_signature
# 0               4
# 1               3
# 2               3
# 3               4
# 4               4
# 5               4
# 6               3
# 7               4
# 8               3
# 9               3
# 10              4
# 11              4
# 12              4
# 13              1
# 14              4
# 15              4
# 16              4
# 17              3
# 18              4
# 19              3
# 20              4
# 21              4
# 22              3
# 23              4
# 24              4
# 25              3
# 26              4
